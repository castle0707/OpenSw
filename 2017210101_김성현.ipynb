# %% [markdown]
# <a href="https://colab.research.google.com/github/castle0707/OpenSw/blob/master/2017210101_%EA%B9%80%EC%84%B1%ED%98%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('final_book_dataset_kaggle.csv')

# %%
df.head()
# Out:
#                                                title  \
# 0  Becoming a Data Head: How to Think Speak and U...
# 1  Ace the Data Science Interview: 201 Real Inter...
# 2  Fundamentals of Data Engineering: Plan and Bui...
# 3  Essential Math for Data Science: Take Control ...
# 4  Data Science for Business: What You Need to Kn...
#
#                               author  price  pages  avg_reviews  n_reviews  \
# 0  [Alex J. Gutman,Jordan Goldmeier]  24.49  272.0          4.6        184
# 1             [Nick Singh,Kevin Huo]  26.00  301.0          4.5        599
# 2            [Joe Reis,Matt Housley]  50.76  446.0          5.0         33
# 3                     [Thomas Nield]  44.80  347.0          4.5         27
# 4       [Foster Provost,Tom Fawcett]  36.99  413.0          4.5        970
#
#    star5  star4  star3  star2  star1             dimensions       weight  \
# 0   0.74   0.18   0.05   0.02   0.01    6 x 0.62 x 9 inches  12.5 ounces
# ...

# %%
df.shape
# Out:
# (946, 18)

# %%
df.sort_values(['price'],ascending=False).head(10)
# Out:
#                                                  title  \
# 885  Using SPSS for Windows and Macintosh (7th Edit...
# 917                                         Statistics
# 867         Introduction to the Practice of Statistics
# 850              Statistics for Business and Economics
# 920  Statistics for Business: Decision Making and A...
# 861                      First Course in Probability A
# 441  Adversarial Deep Learning in Cybersecurity: At...
# 900  Introductory Statistics: Exploring the World T...
# 860                          Stats: Modeling the World
# 180  Ontology-Based Information Retrieval for Healt...
#
#                                                 author   price  pages  \
# 885                  [Samuel B. Green,Neil J. Salkind]  279.95  448.0
# 917                      [James McClave,Terry Sincich]  253.32  896.0
# 867           [David S. Moore,George P. McCabe et al.]  240.34  784.0
# 850            [James McClave,P. George Benson et al.]  223.99  888.0
# ...

# %%
df.sort_values(['pages'],ascending=False).head(10)
# Out:
#                                                  title  \
# 342  C++ Programming: Program Design Including Data...
# 785  Python 3 Standard Library Example The (Develop...
# 366  Numerical Methods Using Java: For Data Science...
# 221  Microsoft Excel Data Analysis and Business Mod...
# 589  Machine Learning: A Bayesian and Optimization ...
# 568  Machine Learning: A Probabilistic Perspective ...
# 247  Econometric Analysis of Cross Section and Pane...
# 895                             Stats: Data and Models
# 840      UPDATED Version of The Practice of Statistics
# 694  Fluent Python: Clear Concise and Effective Pro...
#
#                                 author   price   pages  avg_reviews  \
# 342                      [D. S. Malik]   98.70  1728.0          4.4
# 785                                NaN   51.29  1456.0          4.5
# 366                    [Haksun Li PhD]   32.92  1200.0          5.0
# 221                    [Wayne Winston]   40.99  1168.0          4.6
# ...

# %%
df.sort_values(['avg_reviews'],ascending=False).head(10)
# Out:
#                                                  title  \
# 472  Deep Discourse: A Framework for Cultivating St...
# 97   Introduction to Computation: Haskell Logic and...
# 705  Django 4 Example: Build powerful and reliable ...
# 503  Deep Learning for Physical Scientists: Acceler...
# 714  Computational Cell Physiology: With Examples I...
# 122  Data Science for Librarians (Library and Infor...
# 719  El lenguaje de programaciÃ³n Python de princip...
# 476  Embedded Deep Learning: Algorithms Architectur...
# 468   Deep Learning Applications of Short-range Radars
# 462  Machine Learning at Scale with H2O: A practica...
#
#                                       author   price  pages  avg_reviews  \
# 472              [Sandi Novak,Cara Slattery]   36.95  184.0          5.0
# 97                                       NaN   33.90  382.0          5.0
# 705             [Antonio Mele,Bob Belderbos]   47.18  764.0          5.0
# ...

# %%
df.sort_values(['star5'],ascending=False).head(10)
# Out:
#                                                  title  \
# 429                           Deep Generative Modeling
# 576  Machine Learning for Streaming Data with Pytho...
# 273  Social Statistics: Managing Data Conducting An...
# 68   Video Data Analysis: How to Use 21st Century V...
# 843             Painless Statistics (Barrons Painless)
# 472  Deep Discourse: A Framework for Cultivating St...
# 468   Deep Learning Applications of Short-range Radars
# 462  Machine Learning at Scale with H2O: A practica...
# 745  Mastering Python for Bioinformatics: How to Wr...
# 459  Deep Learning and Physics (Mathematical Physic...
#
#                                  author   price  pages  avg_reviews  \
# 429                  [Jakub M. Tomczak]   70.00  215.0          5.0
# 576                    [Joos Korstanje]   44.99  258.0          5.0
# 273                [Thomas J. Linneman]  105.63  644.0          5.0
# 68   [Anne Nassauer,Nicolas M. Legewie]   45.00  320.0          5.0
# ...

# %%
df.sort_values(['n_reviews','avg_reviews'],ascending=False).head(10)
# Out:
#                                                  title  \
# 127  Cracking the Coding Interview: 189 Programming...
# 104  Python Crash Course 2nd Edition: A Hands-On Pr...
# 813  Clean Code: A Handbook of Agile Software Craft...
# 368  Python: - The Bible- 3 Manuscripts in 1 book: ...
# 237  Storytelling with Data: A Data Visualization G...
# 31   Designing Data-Intensive Applications: The Big...
# 819  Python: For Beginners: A Crash Course Guide To...
# 19       The Art of Statistics: How to Learn from Data
# 827  Automate the Boring Stuff with Python 2nd Edit...
# 320   Python for Everybody: Exploring Data in Python 3
#
#                                                 author  price  pages  \
# 127                          [Gayle Laakmann McDowell]  35.95  687.0
# 104                                     [Eric Matthes]  21.49  544.0
# 813                                                NaN  47.49  464.0
# 368                              [Maurice J. Thompson]  27.97  375.0
# ...

# %%
df.language.value_counts()
# Out:
# English    942
# Spanish      1
# Name: language, dtype: int64

# %%
df.pages.value_counts(bins=5)
# Out:
# (46.319, 384.0]     475
# (384.0, 720.0]      375
# (720.0, 1056.0]      77
# (1056.0, 1392.0]      5
# (1392.0, 1728.0]      2
# Name: pages, dtype: int64

# %%
df.publisher.isna().any().sum()
# Out:
# 1

# %%
df.filter(regex ='[Pearson]').count()
# Out:
# title            946
# author           824
# price            944
# pages            934
# avg_reviews      823
# n_reviews        946
# star5            946
# star4            946
# star3            946
# star2            946
# star1            946
# dimensions       914
# weight           943
# language         943
# publisher        942
# link             946
# complete_link    946
# dtype: int64
